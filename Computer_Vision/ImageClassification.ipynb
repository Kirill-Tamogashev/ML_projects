# %% [markdown]
# ## **Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ**

# %% [markdown]
# # Путешествие по Спрингфилду.
#
#
# Сегодня вам предстоить помочь телекомпании FOX  в обработке их контента. Как вы знаете сериал Симсоны идет на телеэкранах более 25 лет и за это время скопилось очень много видео материала. Персоонажи менялись вместе с изменяющимися графическими технологиями   и Гомер 2018 не очень похож на Гомера 1989. Нашей задачей будет научиться классифицировать персонажей проживающих в Спрингфилде. Думаю, что нет смысла представлять каждого из них в отдельности.
#
#
#
#  ![alt text](https://vignette.wikia.nocookie.net/simpsons/images/5/5a/Spider_fat_piglet.png/revision/latest/scale-to-width-down/640?cb=20111118140828)

# %% [markdown]
# ### Установка зависимостей

# %%
# !pip install -U torch torchvision
# Out:
# Requirement already up-to-date: torch in /usr/local/lib/python3.6/dist-packages (1.7.0+cu101)
# Requirement already up-to-date: torchvision in /usr/local/lib/python3.6/dist-packages (0.8.1+cu101)
# Requirement already satisfied, skipping upgrade: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)
# Requirement already satisfied, skipping upgrade: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (5.3.0)

# %%
# установка подходящей версии torch

from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x58284000 @  0x7fdd11aa72a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641

# %%
# we will verify that GPU is enabled for this notebook
# following should print: CUDA is available!  Training on GPU ...
# 
# if it prints otherwise, then you need to enable GPU: 
# from Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU

import torch
import numpy as np

train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
torch.cuda.empty_cache()

# %%
# нам необходима версия pillow  5.3.0
# удалим старую версию и установим новую
# !pip uninstall -y Pillow
# !pip install Pillow==5.3.0
import PIL
print(PIL.__version__)
# здесь должна быть версия 5.3.0. если это не так перехгрузите данный ноутбук:
# Menu > Runtime > Restart Runtime
# Out:
# Uninstalling Pillow-5.3.0:
#   Successfully uninstalled Pillow-5.3.0
# Collecting Pillow==5.3.0
#   Using cached https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: Pillow
# Successfully installed Pillow-5.3.0
# 7.0.0

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !unzip -q /content/gdrive/MyDrive/journey-springfield.zip -d data
# Out:
# unzip:  cannot find or open /content/gdrive/MyDrive/journey-springfield.zip, /content/gdrive/MyDrive/journey-springfield.zip.zip or /content/gdrive/MyDrive/journey-springfield.zip.ZIP.

# %%
import pickle
import numpy as np
from skimage import io

from tqdm import tqdm, tqdm_notebook
from PIL import Image
from pathlib import Path

from torchvision import transforms
from multiprocessing.pool import ThreadPool
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

from matplotlib import colors, pyplot as plt
# %matplotlib inline

# в sklearn не все гладко, чтобы в colab удобно выводить картинки 
# мы будем игнорировать warnings
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# !ls data
# Out:
# journey-springfield  __MACOSX

# %% [markdown]
# training dataset

# %%
TRAIN_DIR = Path('data/journey-springfield/train')

train_val_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))

# %%
from sklearn.model_selection import train_test_split

train_val_labels = [path.parent.name for path in train_val_files]
train_files, val_files = train_test_split(train_val_files, test_size=0.25, \
                                          stratify=train_val_labels)

# %% [markdown]
# test Dataset

# %%
TEST_DIR = Path('data/journey-springfield/testset/testset')
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))

# %%
len(test_files) , len(train_val_files)
# Out:
# (991, 20933)

# %%
set(train_val_labels)

# %%
# !nvidia-smi
import torch
torch.cuda.is_available()

# %% [markdown]
# В нашем тесте будет 990 картнок, для которых вам будет необходимо предсказать класс.

# %%
# разные режимы датасета 
DATA_MODES = ['train', 'val', 'test']
# все изображения будут масштабированы к размеру 224x224 px
RESCALE_SIZE = 224
# работаем на видеокарте
DEVICE = torch.device("cuda")

# %% [markdown]
# https://jhui.github.io/2018/02/09/PyTorch-Data-loading-preprocess_torchvision/

# %% [markdown]
# Ниже мы исспользуем враппер над датасетом для удобной работы. Вам стоит понимать, что происходит с LabelEncoder и  с torch.Transformation.
#
# ToTensor конвертирует  PIL Image с параметрами в диапазоне [0, 255] (как все пиксели) в FloatTensor размера (C x H x W) [0,1] , затем производится масштабирование:
# $input = \frac{input - \mu}{\text{standard deviation}} $, <br>       константы - средние и дисперсии по каналам на основе ImageNet
#
#
# Стоит также отметить, что мы переопределяем метод __getitem__ для удобства работы с данной структурой данных.
#  Также используется LabelEncoder для преобразования строковых меток классов в id и обратно. В описании датасета указано, что картинки разного размера, так как брались напрямую с видео, поэтому следуем привести их к одному размер (это делает метод  _prepare_sample)

# %%
class SimpsonsDataset(Dataset):
    """
    Датасет с картинками, который паралельно подгружает их из папок
    производит скалирование и превращение в торчевые тензоры
    """
    def __init__(self, files, mode):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files)
        # режим работы
        self.mode = mode

        if self.mode not in DATA_MODES:
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.len_ = len(self.files)
     
        self.label_encoder = LabelEncoder()

        if self.mode != 'test':
            self.labels = [path.parent.name for path in self.files]
            self.label_encoder.fit(self.labels)

            with open('label_encoder.pkl', 'wb') as le_dump_file:
                  pickle.dump(self.label_encoder, le_dump_file)
                      
    def __len__(self):
        return self.len_
      
    def load_sample(self, file):
        image = Image.open(file)
        image.load()
        return image
  
    def __getitem__(self, index):
        # для преобразования изображений в тензоры PyTorch и нормализации входа
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
        ])
        x = self.load_sample(self.files[index])
        x = self._prepare_sample(x)
        x = np.array(x / 255, dtype='float32')
        x = transform(x)
        if self.mode == 'test':
            return x
        else:
            label = self.labels[index]
            label_id = self.label_encoder.transform([label])
            y = label_id.item()
            return x, y
        
    def _prepare_sample(self, image):
        image = image.resize((RESCALE_SIZE, RESCALE_SIZE))
        return np.array(image)

# %%
def imshow(inp, title=None, plt_ax=plt, default=False):
    """Imshow для тензоров"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt_ax.imshow(inp)
    if title is not None:
        plt_ax.set_title(title)
    plt_ax.grid(False)

# %%
val_dataset = SimpsonsDataset(val_files, mode='val')

# %%
# uncomment if you have problem with pillow

# def register_extension(id, extension): Image.EXTENSION[extension.lower()] = id.upper()
# Image.register_extension = register_extension
# def register_extensions(id, extensions): 
#     for extension in extensions: register_extension(id, extension)
# Image.register_extensions = register_extensions

# %% [markdown]
# Давайте посмотрим на наших героев внутри датасета.

# %%
fig, ax = plt.subplots(nrows=4, ncols=4,figsize=(12, 12), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    random_characters = int(np.random.uniform(0,1000))
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)

# %% [markdown]
# Можете добавить ваши любимые сцены и классифицировать их. (веселые результаты можно кидать в чат)

# %% [markdown]
# ### Построение нейросети
#
# Запустить данную сеть будет вашим мини-заданием на первую неделю, чтобы было проще участвовать в соревновании.
#
# Данная архитектура будет очень простой и нужна для того, чтобы установить базовое понимание и получить простенький сабмит на Kaggle
#
# <!-- Здесь вам предлагается дописать сверточную сеть глубины 4/5.  -->
#
# *Описание слоев*:
#
#
#
# 1. размерность входа: 3x224x224
# 2.размерности после слоя:  8x111x111
# 3. 16x54x54
# 4. 32x26x26
# 5. 64x12x12
# 6. выход: 96x5x5

# %%
# Очень простая сеть
class SimpleCnn(nn.Module):
  
    def __init__(self, n_classes):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        
        self.out = nn.Linear(96 * 5 * 5, n_classes)
  
  
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)

        x = x.view(x.size(0), -1)
        logits = self.out(x)
        return logits

# %%
def fit_epoch(model, train_loader, criterion, optimizer):
    running_loss = 0.0
    running_corrects = 0
    processed_data = 0
  
    for inputs, labels in train_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        preds = torch.argmax(outputs, 1)
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_data += inputs.size(0)
              
    train_loss = running_loss / processed_data
    train_acc = running_corrects.cpu().numpy() / processed_data
    return train_loss, train_acc

# %%
def eval_epoch(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    processed_size = 0

    for inputs, labels in val_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, 1)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_size += inputs.size(0)
    val_loss = running_loss / processed_size
    val_acc = running_corrects.double() / processed_size
    return val_loss, val_acc

# %%
def train(train_files, val_files, model, epochs, batch_size):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} train_loss: {t_loss:0.4f} \
    val_loss {v_loss:0.4f} train_acc {t_acc:0.4f} val_acc {v_acc:0.4f}"

    with tqdm(desc="epoch", total=epochs) as pbar_outer:
        optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
        #lr_lambda = lambda epoch: 0.8
        #scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda)
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            train_loss, train_acc = fit_epoch(model, train_loader, criterion, optimizer)
            print("loss", train_loss)
            
            val_loss, val_acc = eval_epoch(model, val_loader, criterion)
            history.append((train_loss, train_acc, val_loss, val_acc))
            
            #scheduler.step()

            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=train_loss,\
                                           v_loss=val_loss, t_acc=train_acc, v_acc=val_acc))
            
    return history

# %%
def predict(model, test_loader):
    with torch.no_grad():
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(DEVICE)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %%
n_classes = len(np.unique(train_val_labels))
simple_cnn = SimpleCnn(n_classes).to(DEVICE)
print("we will classify :{}".format(n_classes))
print(simple_cnn)
# Out:
# we will classify :43
# SimpleCnn(
#   (conv1): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=2400, out_features=43, bias=True)
# )

# %% [markdown]
# Запустим обучение сети.

# %%
if val_dataset is None:
    val_dataset = SimpsonsDataset(val_files, mode='val')
    
train_dataset = SimpsonsDataset(train_files, mode='train')

# %%
import torchvision.models as models
resnet50 = models.resnet50(pretrained=True)
resnet50 = resnet50.to(DEVICE)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
history = train(train_dataset, val_dataset, model=resnet50, epochs=10, batch_size=128)
# Out:
# epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# loss 1.1335436421614922
# epoch:  10%|█         | 1/10 [04:46<43:02, 286.98s/it]
# Epoch 001 train_loss: 1.1335     val_loss 0.2434 train_acc 0.8127 val_acc 0.9421
# loss 0.22977197297827226
# epoch:  20%|██        | 2/10 [09:32<38:11, 286.46s/it]
# Epoch 002 train_loss: 0.2298     val_loss 0.2528 train_acc 0.9396 val_acc 0.9383
# loss 0.10235837530300824
# epoch:  30%|███       | 3/10 [14:17<33:21, 285.97s/it]
# Epoch 003 train_loss: 0.1024     val_loss 0.1872 train_acc 0.9725 val_acc 0.9564
# loss 0.061349101505328366
# epoch:  40%|████      | 4/10 [19:01<28:33, 285.61s/it]
# Epoch 004 train_loss: 0.0613     val_loss 0.2176 train_acc 0.9841 val_acc 0.9526
# loss 0.043029097853359795
# epoch:  50%|█████     | 5/10 [23:47<23:47, 285.60s/it]
# Epoch 005 train_loss: 0.0430     val_loss 0.1762 train_acc 0.9876 val_acc 0.9574
# loss 0.04010458674080847
# epoch:  60%|██████    | 6/10 [28:32<19:01, 285.34s/it]
# Epoch 006 train_loss: 0.0401     val_loss 0.3630 train_acc 0.9884 val_acc 0.9186
# loss 0.050822405298279937
# epoch:  70%|███████   | 7/10 [33:16<14:15, 285.11s/it]
# Epoch 007 train_loss: 0.0508     val_loss 0.1750 train_acc 0.9850 val_acc 0.9627
# loss 0.023971777082923595
# epoch:  80%|████████  | 8/10 [38:01<09:29, 284.98s/it]
# Epoch 008 train_loss: 0.0240     val_loss 0.1872 train_acc 0.9933 val_acc 0.9627
# loss 0.01093491638843434
# epoch:  90%|█████████ | 9/10 [42:48<04:45, 285.58s/it]
# Epoch 009 train_loss: 0.0109     val_loss 0.1560 train_acc 0.9969 val_acc 0.9700
# loss 0.029688250216456047
# epoch: 100%|██████████| 10/10 [47:39<00:00, 285.91s/it]
# Epoch 010 train_loss: 0.0297     val_loss 0.2164 train_acc 0.9917 val_acc 0.9582

# %% [markdown]
# Построим кривые обучения

# %%
loss, acc, val_loss, val_acc = zip(*history)

# %%
plt.style.use('ggplot')
plt.figure(figsize=(15, 9))
plt.plot(loss, label="train_loss")
plt.plot(val_loss, label="val_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ### Ну и что теперь со всем этим делать?

# %% [markdown]
# ![alt text](https://www.indiewire.com/wp-content/uploads/2014/08/the-simpsons.jpg)

# %% [markdown]
# Хорошо бы понять, как сделать сабмит.
# У нас есть сеть и методы eval у нее, которые позволяют перевести сеть в режим предсказания. Стоит понимать, что у нашей модели на последнем слое стоит softmax, которые позволяет получить вектор вероятностей  того, что объект относится к тому или иному классу. Давайте воспользуемся этим.

# %%
def predict_one_sample(model, inputs, device=DEVICE):
    """Предсказание, для одной картинки"""
    with torch.no_grad():
        inputs = inputs.to(device)
        model.eval()
        logit = model(inputs).cpu()
        probs = torch.nn.functional.softmax(logit, dim=-1).numpy()
    return probs

# %%
random_characters = int(np.random.uniform(0,1000))
ex_img, true_label = val_dataset[random_characters]
probs_im = predict_one_sample(resnet50, ex_img.unsqueeze(0))

# %%
idxs = list(map(int, np.random.uniform(0,1000, 200)))
imgs = [val_dataset[id][0].unsqueeze(0) for id in idxs]

probs_ims = predict(resnet50, imgs)

# %%
label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))

# %%
y_pred = np.argmax(probs_ims,-1)

actual_labels = [val_dataset[id][1] for id in idxs]

preds_class = [label_encoder.classes_[i] for i in y_pred]

# %% [markdown]
# Обратите внимание, что метрика, которую необходимо оптимизировать в конкурсе --- f1-score. Вычислим целевую метрику на валидационной выборке.

# %%
from sklearn.metrics import f1_score

f1_score(actual_labels, y_pred, average='micro')
# Out:
# 0.945

# %% [markdown]
# Сделаем классную визуализацию,  чтобы посмотреть насколько сеть уверена в своих ответах. Можете исспользовать это, чтобы отлаживать правильность вывода.

# %%
import matplotlib.patches as patches
from matplotlib.font_manager import FontProperties

fig, ax = plt.subplots(nrows=5, ncols=5,figsize=(20, 20), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    random_characters = int(np.random.uniform(0,1000))
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    
    

    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)
    
    actual_text = "Actual : {}".format(img_label)
            
    fig_x.add_patch(patches.Rectangle((0, 53),86,35,color='white'))
    font0 = FontProperties()
    font = font0.copy()
    font.set_family("fantasy")
    prob_pred = predict_one_sample(resnet50, im_val.unsqueeze(0))
    predicted_proba = np.max(prob_pred)*100
    y_pred = np.argmax(prob_pred)
    
    predicted_label = label_encoder.classes_[y_pred]
    predicted_label = predicted_label[:len(predicted_label)//2] + '\n' + predicted_label[len(predicted_label)//2:]
    predicted_text = "{} : {:.0f}%".format(predicted_label,predicted_proba)
            
    fig_x.text(1, 59, predicted_text , horizontalalignment='left', fontproperties=font,
                    verticalalignment='top',fontsize=8, color='black',fontweight='bold')

# %% [markdown]
# Попробуйте найти те классы, которые сеть не смогла расспознать. Изучите данную проблему, это понадобится в дальнейшем.

# %% [markdown]
# ### Submit на Kaggle

# %% [markdown]
# ![alt text](https://i.redd.it/nuaphfioz0211.jpg)

# %%
test_dataset = SimpsonsDataset(test_files, mode="test")
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)
probs = predict(resnet50, test_loader)


preds = label_encoder.inverse_transform(np.argmax(probs, axis=1))
test_filenames = [path.name for path in test_dataset.files]

# %%
# Out:
# array(['nelson_muntz', 'bart_simpson', 'ned_flanders', 'chief_wiggum',
#        'apu_nahasapeemapetilon', 'kent_brockman', 'edna_krabappel',
#        'chief_wiggum', 'lisa_simpson', 'kent_brockman', 'lenny_leonard',
#        'marge_simpson', 'kent_brockman', 'ned_flanders', 'moe_szyslak',
#        'comic_book_guy', 'abraham_grampa_simpson', 'edna_krabappel',
#        'kent_brockman', 'lisa_simpson', 'marge_simpson', 'nelson_muntz',
#        'comic_book_guy', 'mayor_quimby', 'homer_simpson',
#        'apu_nahasapeemapetilon', 'krusty_the_clown', 'krusty_the_clown',
#        'ned_flanders', 'edna_krabappel', 'apu_nahasapeemapetilon',
#        'chief_wiggum', 'apu_nahasapeemapetilon', 'ned_flanders',
#        'marge_simpson', 'abraham_grampa_simpson', 'homer_simpson',
#        'sideshow_bob', 'lisa_simpson', 'charles_montgomery_burns',
#        'chief_wiggum', 'kent_brockman', 'abraham_grampa_simpson',
#        'milhouse_van_houten', 'lenny_leonard', 'abraham_grampa_simpson',
#        'nelson_muntz', 'comic_book_guy', 'chief_wiggum', 'nelson_muntz',
#        'mayor_quimby', 'charles_montgomery_burns',
#        'apu_nahasapeemapetilon', 'mayor_quimby', 'bart_simpson',
#        'edna_krabappel', 'edna_krabappel', 'charles_montgomery_burns',
#        'ned_flanders', 'chief_wiggum', 'homer_simpson',
#        'charles_montgomery_burns', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'lenny_leonard', 'nelson_muntz',
#        'comic_book_guy', 'kent_brockman', 'mayor_quimby', 'sideshow_bob',
#        'ned_flanders', 'ned_flanders', 'comic_book_guy',
#        'charles_montgomery_burns', 'edna_krabappel', 'bart_simpson',
#        'kent_brockman', 'ned_flanders', 'krusty_the_clown',
#        'comic_book_guy', 'chief_wiggum', 'mayor_quimby', 'ned_flanders',
#        'krusty_the_clown', 'sideshow_bob', 'ned_flanders', 'chief_wiggum',
#        'nelson_muntz', 'abraham_grampa_simpson', 'krusty_the_clown',
#        'homer_simpson', 'krusty_the_clown', 'lisa_simpson',
#        'krusty_the_clown', 'mayor_quimby', 'lisa_simpson', 'moe_szyslak',
#        'nelson_muntz', 'marge_simpson', 'bart_simpson', 'chief_wiggum',
#        'milhouse_van_houten', 'chief_wiggum', 'kent_brockman',
#        'marge_simpson', 'lisa_simpson', 'apu_nahasapeemapetilon',
#        'charles_montgomery_burns', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'mayor_quimby', 'marge_simpson',
#        'edna_krabappel', 'homer_simpson', 'lisa_simpson', 'bart_simpson',
#        'principal_skinner', 'edna_krabappel', 'milhouse_van_houten',
#        'moe_szyslak', 'lenny_leonard', 'moe_szyslak', 'principal_skinner',
#        'homer_simpson', 'lenny_leonard', 'lisa_simpson', 'sideshow_bob',
#        'chief_wiggum', 'apu_nahasapeemapetilon', 'mayor_quimby',
#        'lisa_simpson', 'mayor_quimby', 'kent_brockman', 'moe_szyslak',
#        'homer_simpson', 'lisa_simpson', 'milhouse_van_houten',
#        'apu_nahasapeemapetilon', 'mayor_quimby',
#        'charles_montgomery_burns', 'charles_montgomery_burns',
#        'bart_simpson', 'kent_brockman', 'lisa_simpson', 'chief_wiggum',
#        'moe_szyslak', 'sideshow_bob', 'lisa_simpson', 'edna_krabappel',
#        'krusty_the_clown', 'kent_brockman', 'homer_simpson',
#        'charles_montgomery_burns', 'moe_szyslak', 'nelson_muntz',
#        'chief_wiggum', 'nelson_muntz', 'mayor_quimby', 'homer_simpson',
#        'nelson_muntz', 'marge_simpson', 'comic_book_guy', 'homer_simpson',
#        'charles_montgomery_burns', 'lenny_leonard', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'nelson_muntz', 'mayor_quimby',
#        'bart_simpson', 'apu_nahasapeemapetilon', 'homer_simpson',
#        'lenny_leonard', 'milhouse_van_houten', 'krusty_the_clown',
#        'abraham_grampa_simpson', 'lisa_simpson', 'abraham_grampa_simpson',
#        'chief_wiggum', 'homer_simpson', 'homer_simpson',
#        'krusty_the_clown', 'lenny_leonard', 'lenny_leonard',
#        'kent_brockman', 'charles_montgomery_burns', 'sideshow_bob',
#        'chief_wiggum', 'edna_krabappel', 'kent_brockman',
#        'apu_nahasapeemapetilon', 'nelson_muntz', 'bart_simpson',
#        'charles_montgomery_burns', 'mayor_quimby', 'mayor_quimby',
#        'chief_wiggum', 'bart_simpson', 'abraham_grampa_simpson',
#        'homer_simpson', 'nelson_muntz', 'abraham_grampa_simpson',
#        'marge_simpson', 'chief_wiggum', 'lenny_leonard', 'ned_flanders',
#        'moe_szyslak', 'marge_simpson', 'marge_simpson', 'kent_brockman',
#        'moe_szyslak', 'charles_montgomery_burns', 'comic_book_guy',
#        'apu_nahasapeemapetilon', 'bart_simpson', 'edna_krabappel',
#        'principal_skinner', 'nelson_muntz', 'comic_book_guy',
#        'moe_szyslak', 'krusty_the_clown', 'nelson_muntz',
#        'krusty_the_clown', 'milhouse_van_houten', 'marge_simpson',
#        'bart_simpson', 'krusty_the_clown', 'edna_krabappel',
#        'nelson_muntz', 'marge_simpson', 'apu_nahasapeemapetilon',
#        'sideshow_bob', 'homer_simpson', 'comic_book_guy',
#        'edna_krabappel', 'lisa_simpson', 'kent_brockman',
#        'milhouse_van_houten', 'apu_nahasapeemapetilon', 'moe_szyslak',
#        'apu_nahasapeemapetilon', 'edna_krabappel', 'krusty_the_clown',
#        'comic_book_guy', 'lisa_simpson', 'nelson_muntz',
#        'charles_montgomery_burns', 'bart_simpson', 'nelson_muntz',
#        'nelson_muntz', 'moe_szyslak', 'moe_szyslak',
#        'charles_montgomery_burns', 'edna_krabappel', 'ned_flanders',
#        'marge_simpson', 'apu_nahasapeemapetilon', 'milhouse_van_houten',
#        'moe_szyslak', 'moe_szyslak', 'comic_book_guy',
#        'principal_skinner', 'marge_simpson', 'krusty_the_clown',
#        'ned_flanders', 'principal_skinner', 'edna_krabappel',
#        'marge_simpson', 'bart_simpson', 'lisa_simpson', 'kent_brockman',
#        'mayor_quimby', 'comic_book_guy', 'lenny_leonard', 'chief_wiggum',
#        'charles_montgomery_burns', 'sideshow_bob', 'sideshow_bob',
#        'principal_skinner', 'homer_simpson', 'krusty_the_clown',
#        'homer_simpson', 'abraham_grampa_simpson', 'principal_skinner',
#        'homer_simpson', 'edna_krabappel', 'charles_montgomery_burns',
#        'krusty_the_clown', 'chief_wiggum', 'nelson_muntz',
#        'lenny_leonard', 'ned_flanders', 'chief_wiggum', 'sideshow_bob',
#        'lisa_simpson', 'lenny_leonard', 'sideshow_bob', 'sideshow_bob',
#        'homer_simpson', 'moe_szyslak', 'ned_flanders', 'nelson_muntz',
#        'lenny_leonard', 'lenny_leonard', 'kent_brockman',
#        'abraham_grampa_simpson', 'nelson_muntz', 'ned_flanders',
#        'kent_brockman', 'bart_simpson', 'moe_szyslak',
#        'principal_skinner', 'sideshow_bob', 'lisa_simpson',
#        'principal_skinner', 'sideshow_bob', 'bart_simpson',
#        'lisa_simpson', 'bart_simpson', 'marge_simpson',
#        'principal_skinner', 'moe_szyslak', 'lisa_simpson',
#        'apu_nahasapeemapetilon', 'principal_skinner',
#        'abraham_grampa_simpson', 'lenny_leonard', 'lisa_simpson',
#        'lenny_leonard', 'edna_krabappel', 'mayor_quimby', 'bart_simpson',
#        'lisa_simpson', 'moe_szyslak', 'abraham_grampa_simpson',
#        'chief_wiggum', 'krusty_the_clown', 'milhouse_van_houten',
#        'mayor_quimby', 'principal_skinner', 'edna_krabappel',
#        'comic_book_guy', 'comic_book_guy', 'kent_brockman',
#        'ned_flanders', 'principal_skinner', 'kent_brockman',
#        'krusty_the_clown', 'nelson_muntz', 'milhouse_van_houten',
#        'sideshow_bob', 'mayor_quimby', 'lenny_leonard', 'bart_simpson',
#        'lenny_leonard', 'comic_book_guy', 'principal_skinner',
#        'bart_simpson', 'milhouse_van_houten', 'lenny_leonard',
#        'edna_krabappel', 'abraham_grampa_simpson', 'marge_simpson',
#        'mayor_quimby', 'marge_simpson', 'kent_brockman', 'mayor_quimby',
#        'homer_simpson', 'krusty_the_clown', 'krusty_the_clown',
#        'milhouse_van_houten', 'lisa_simpson', 'ned_flanders',
#        'lisa_simpson', 'principal_skinner', 'krusty_the_clown',
#        'lenny_leonard', 'edna_krabappel', 'sideshow_bob', 'marge_simpson',
#        'comic_book_guy', 'apu_nahasapeemapetilon', 'chief_wiggum',
#        'lisa_simpson', 'milhouse_van_houten', 'comic_book_guy',
#        'mayor_quimby', 'sideshow_bob', 'edna_krabappel', 'sideshow_bob',
#        'abraham_grampa_simpson', 'edna_krabappel', 'comic_book_guy',
#        'moe_szyslak', 'ned_flanders', 'moe_szyslak', 'ned_flanders',
#        'mayor_quimby', 'ned_flanders', 'krusty_the_clown',
#        'edna_krabappel', 'principal_skinner', 'lisa_simpson',
#        'principal_skinner', 'edna_krabappel', 'lenny_leonard',
#        'milhouse_van_houten', 'kent_brockman', 'sideshow_bob',
#        'principal_skinner', 'principal_skinner', 'principal_skinner',
#        'homer_simpson', 'homer_simpson', 'sideshow_bob',
#        'milhouse_van_houten', 'bart_simpson', 'moe_szyslak',
#        'lisa_simpson', 'charles_montgomery_burns',
#        'apu_nahasapeemapetilon', 'mayor_quimby', 'milhouse_van_houten',
#        'charles_montgomery_burns', 'comic_book_guy',
#        'abraham_grampa_simpson', 'marge_simpson', 'principal_skinner',
#        'charles_montgomery_burns', 'krusty_the_clown', 'lisa_simpson',
#        'abraham_grampa_simpson', 'milhouse_van_houten', 'lisa_simpson',
#        'apu_nahasapeemapetilon', 'lisa_simpson', 'principal_skinner',
#        'kent_brockman', 'nelson_muntz', 'comic_book_guy',
#        'milhouse_van_houten', 'lisa_simpson', 'comic_book_guy',
#        'principal_skinner', 'lisa_simpson', 'abraham_grampa_simpson',
#        'edna_krabappel', 'ned_flanders', 'krusty_the_clown',
#        'bart_simpson', 'lisa_simpson', 'lenny_leonard', 'homer_simpson',
#        'apu_nahasapeemapetilon', 'comic_book_guy', 'comic_book_guy',
#        'bart_simpson', 'marge_simpson', 'carl_carlson', 'bart_simpson',
#        'chief_wiggum', 'lisa_simpson', 'kent_brockman',
#        'krusty_the_clown', 'krusty_the_clown', 'milhouse_van_houten',
#        'milhouse_van_houten', 'kent_brockman', 'edna_krabappel',
#        'lisa_simpson', 'principal_skinner', 'bart_simpson',
#        'abraham_grampa_simpson', 'milhouse_van_houten', 'chief_wiggum',
#        'apu_nahasapeemapetilon', 'charles_montgomery_burns',
#        'krusty_the_clown', 'ned_flanders', 'comic_book_guy',
#        'homer_simpson', 'bart_simpson', 'abraham_grampa_simpson',
#        'lenny_leonard', 'ned_flanders', 'chief_wiggum', 'lenny_leonard',
#        'moe_szyslak', 'milhouse_van_houten', 'lisa_simpson',
#        'homer_simpson', 'nelson_muntz', 'abraham_grampa_simpson',
#        'principal_skinner', 'nelson_muntz', 'kent_brockman',
#        'krusty_the_clown', 'homer_simpson', 'marge_simpson',
#        'sideshow_bob', 'ned_flanders', 'lenny_leonard',
#        'milhouse_van_houten', 'krusty_the_clown',
#        'apu_nahasapeemapetilon', 'mayor_quimby', 'chief_wiggum',
#        'bart_simpson', 'marge_simpson', 'milhouse_van_houten',
#        'nelson_muntz', 'mayor_quimby', 'krusty_the_clown',
#        'kent_brockman', 'moe_szyslak', 'apu_nahasapeemapetilon',
#        'mayor_quimby', 'sideshow_bob', 'mayor_quimby',
#        'principal_skinner', 'mayor_quimby', 'lisa_simpson',
#        'apu_nahasapeemapetilon', 'nelson_muntz', 'abraham_grampa_simpson',
#        'ned_flanders', 'moe_szyslak', 'abraham_grampa_simpson',
#        'kent_brockman', 'abraham_grampa_simpson', 'moe_szyslak',
#        'comic_book_guy', 'kent_brockman', 'krusty_the_clown',
#        'chief_wiggum', 'homer_simpson', 'lisa_simpson', 'lenny_leonard',
#        'apu_nahasapeemapetilon', 'comic_book_guy',
#        'apu_nahasapeemapetilon', 'abraham_grampa_simpson', 'nelson_muntz',
#        'bart_simpson', 'moe_szyslak', 'chief_wiggum', 'ned_flanders',
#        'principal_skinner', 'kent_brockman', 'ned_flanders',
#        'charles_montgomery_burns', 'comic_book_guy', 'krusty_the_clown',
#        'bart_simpson', 'krusty_the_clown', 'bart_simpson', 'chief_wiggum',
#        'apu_nahasapeemapetilon', 'moe_szyslak', 'homer_simpson',
#        'principal_skinner', 'comic_book_guy', 'abraham_grampa_simpson',
#        'homer_simpson', 'apu_nahasapeemapetilon', 'bart_simpson',
#        'chief_wiggum', 'chief_wiggum', 'homer_simpson', 'marge_simpson',
#        'abraham_grampa_simpson', 'mayor_quimby', 'lisa_simpson',
#        'charles_montgomery_burns', 'chief_wiggum', 'ned_flanders',
#        'sideshow_bob', 'chief_wiggum', 'krusty_the_clown', 'bart_simpson',
#        'marge_simpson', 'ned_flanders', 'mayor_quimby', 'mayor_quimby',
#        'nelson_muntz', 'abraham_grampa_simpson', 'ned_flanders',
#        'lenny_leonard', 'abraham_grampa_simpson', 'bart_simpson',
#        'mayor_quimby', 'lenny_leonard', 'abraham_grampa_simpson',
#        'ned_flanders', 'sideshow_bob', 'homer_simpson', 'homer_simpson',
#        'lisa_simpson', 'homer_simpson', 'lisa_simpson', 'ned_flanders',
#        'nelson_muntz', 'moe_szyslak', 'chief_wiggum',
#        'apu_nahasapeemapetilon', 'sideshow_bob', 'chief_wiggum',
#        'marge_simpson', 'krusty_the_clown', 'marge_simpson',
#        'abraham_grampa_simpson', 'sideshow_bob', 'lenny_leonard',
#        'lenny_leonard', 'charles_montgomery_burns', 'kent_brockman',
#        'principal_skinner', 'ned_flanders', 'lisa_simpson',
#        'lenny_leonard', 'charles_montgomery_burns', 'principal_skinner',
#        'nelson_muntz', 'edna_krabappel', 'comic_book_guy', 'chief_wiggum',
#        'homer_simpson', 'edna_krabappel', 'sideshow_bob', 'moe_szyslak',
#        'comic_book_guy', 'moe_szyslak', 'milhouse_van_houten',
#        'charles_montgomery_burns', 'kent_brockman', 'milhouse_van_houten',
#        'homer_simpson', 'nelson_muntz', 'charles_montgomery_burns',
#        'moe_szyslak', 'nelson_muntz', 'ned_flanders', 'nelson_muntz',
#        'mayor_quimby', 'kent_brockman', 'apu_nahasapeemapetilon',
#        'homer_simpson', 'sideshow_bob', 'homer_simpson', 'nelson_muntz',
#        'lenny_leonard', 'kent_brockman', 'moe_szyslak', 'bart_simpson',
#        'bart_simpson', 'kent_brockman', 'nelson_muntz',
#        'charles_montgomery_burns', 'milhouse_van_houten',
#        'milhouse_van_houten', 'principal_skinner', 'kent_brockman',
#        'krusty_the_clown', 'milhouse_van_houten', 'bart_simpson',
#        'apu_nahasapeemapetilon', 'abraham_grampa_simpson',
#        'abraham_grampa_simpson', 'kent_brockman',
#        'apu_nahasapeemapetilon', 'comic_book_guy', 'mayor_quimby',
#        'moe_szyslak', 'kent_brockman', 'milhouse_van_houten',
#        'apu_nahasapeemapetilon', 'marge_simpson', 'lisa_simpson',
#        'moe_szyslak', 'lenny_leonard', 'lenny_leonard',
#        'milhouse_van_houten', 'charles_montgomery_burns',
#        'edna_krabappel', 'mayor_quimby', 'moe_szyslak',
#        'apu_nahasapeemapetilon', 'principal_skinner', 'kent_brockman',
#        'lenny_leonard', 'edna_krabappel', 'mayor_quimby', 'homer_simpson',
#        'comic_book_guy', 'krusty_the_clown', 'lenny_leonard',
#        'abraham_grampa_simpson', 'charles_montgomery_burns',
#        'bart_simpson', 'kent_brockman', 'apu_nahasapeemapetilon',
#        'apu_nahasapeemapetilon', 'sideshow_bob', 'edna_krabappel',
#        'charles_montgomery_burns', 'comic_book_guy', 'sideshow_bob',
#        'comic_book_guy', 'chief_wiggum', 'bart_simpson',
#        'abraham_grampa_simpson', 'abraham_grampa_simpson', 'mayor_quimby',
#        'edna_krabappel', 'edna_krabappel', 'abraham_grampa_simpson',
#        'lenny_leonard', 'lisa_simpson', 'milhouse_van_houten',
#        'mayor_quimby', 'apu_nahasapeemapetilon', 'krusty_the_clown',
#        'mayor_quimby', 'sideshow_bob', 'sideshow_bob',
#        'principal_skinner', 'chief_wiggum', 'charles_montgomery_burns',
#        'comic_book_guy', 'chief_wiggum', 'krusty_the_clown',
#        'marge_simpson', 'ned_flanders', 'principal_skinner',
#        'kent_brockman', 'moe_szyslak', 'edna_krabappel', 'chief_wiggum',
#        'ned_flanders', 'bart_simpson', 'bart_simpson', 'marge_simpson',
#        'moe_szyslak', 'edna_krabappel', 'abraham_grampa_simpson',
#        'bart_simpson', 'comic_book_guy', 'abraham_grampa_simpson',
#        'lisa_simpson', 'milhouse_van_houten', 'nelson_muntz',
#        'kent_brockman', 'principal_skinner', 'kent_brockman',
#        'charles_montgomery_burns', 'milhouse_van_houten',
#        'principal_skinner', 'bart_simpson', 'lenny_leonard',
#        'chief_wiggum', 'milhouse_van_houten', 'ned_flanders',
#        'principal_skinner', 'kent_brockman', 'edna_krabappel',
#        'mayor_quimby', 'comic_book_guy', 'charles_montgomery_burns',
#        'chief_wiggum', 'homer_simpson', 'sideshow_bob', 'ned_flanders',
#        'nelson_muntz', 'moe_szyslak', 'principal_skinner', 'sideshow_bob',
#        'principal_skinner', 'milhouse_van_houten',
#        'abraham_grampa_simpson', 'homer_simpson', 'chief_wiggum',
#        'milhouse_van_houten', 'edna_krabappel', 'moe_szyslak',
#        'milhouse_van_houten', 'selma_bouvier', 'principal_skinner',
#        'edna_krabappel', 'principal_skinner', 'lisa_simpson',
#        'comic_book_guy', 'apu_nahasapeemapetilon', 'edna_krabappel',
#        'kent_brockman', 'principal_skinner', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'homer_simpson', 'milhouse_van_houten',
#        'bart_simpson', 'edna_krabappel', 'moe_szyslak', 'marge_simpson',
#        'ned_flanders', 'homer_simpson', 'comic_book_guy',
#        'apu_nahasapeemapetilon', 'comic_book_guy', 'homer_simpson',
#        'sideshow_bob', 'bart_simpson', 'abraham_grampa_simpson',
#        'chief_wiggum', 'nelson_muntz', 'charles_montgomery_burns',
#        'edna_krabappel', 'abraham_grampa_simpson', 'edna_krabappel',
#        'bart_simpson', 'moe_szyslak', 'charles_montgomery_burns',
#        'chief_wiggum', 'lisa_simpson', 'abraham_grampa_simpson',
#        'ned_flanders', 'kent_brockman', 'krusty_the_clown',
#        'mayor_quimby', 'comic_book_guy', 'marge_simpson',
#        'charles_montgomery_burns', 'chief_wiggum', 'marge_simpson',
#        'sideshow_bob', 'lenny_leonard', 'lisa_simpson',
#        'principal_skinner', 'abraham_grampa_simpson', 'kent_brockman',
#        'mayor_quimby', 'marge_simpson', 'sideshow_bob', 'marge_simpson',
#        'lisa_simpson', 'mayor_quimby', 'charles_montgomery_burns',
#        'marge_simpson', 'lenny_leonard', 'edna_krabappel',
#        'krusty_the_clown', 'marge_simpson', 'nelson_muntz',
#        'krusty_the_clown', 'lisa_simpson', 'lisa_simpson', 'nelson_muntz',
#        'marge_simpson', 'milhouse_van_houten', 'comic_book_guy',
#        'lisa_simpson', 'homer_simpson', 'apu_nahasapeemapetilon',
#        'lenny_leonard', 'sideshow_bob', 'abraham_grampa_simpson',
#        'chief_wiggum', 'lisa_simpson', 'lisa_simpson', 'kent_brockman',
#        'homer_simpson', 'marge_simpson', 'bart_simpson',
#        'principal_skinner', 'homer_simpson', 'charles_montgomery_burns',
#        'principal_skinner', 'sideshow_bob', 'ned_flanders',
#        'bart_simpson', 'krusty_the_clown', 'bart_simpson', 'sideshow_bob',
#        'abraham_grampa_simpson', 'abraham_grampa_simpson',
#        'milhouse_van_houten', 'moe_szyslak', 'ned_flanders',
#        'comic_book_guy', 'nelson_muntz', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'moe_szyslak',
#        'charles_montgomery_burns', 'nelson_muntz', 'comic_book_guy',
#        'principal_skinner', 'ned_flanders', 'moe_szyslak', 'sideshow_bob',
#        'ned_flanders', 'moe_szyslak', 'chief_wiggum', 'mayor_quimby',
#        'lisa_simpson', 'bart_simpson', 'marge_simpson', 'mayor_quimby',
#        'apu_nahasapeemapetilon', 'krusty_the_clown', 'sideshow_bob',
#        'lisa_simpson', 'moe_szyslak', 'lenny_leonard',
#        'charles_montgomery_burns', 'comic_book_guy', 'lisa_simpson',
#        'krusty_the_clown', 'comic_book_guy', 'mayor_quimby',
#        'kent_brockman', 'sideshow_bob', 'bart_simpson', 'comic_book_guy',
#        'ned_flanders', 'edna_krabappel', 'edna_krabappel', 'moe_szyslak',
#        'kent_brockman', 'milhouse_van_houten', 'edna_krabappel',
#        'edna_krabappel', 'milhouse_van_houten', 'lisa_simpson',
#        'kent_brockman', 'lisa_simpson', 'principal_skinner',
#        'lenny_leonard', 'lisa_simpson', 'homer_simpson', 'ned_flanders',
#        'sideshow_bob', 'comic_book_guy', 'comic_book_guy', 'chief_wiggum',
#        'lenny_leonard', 'abraham_grampa_simpson', 'marge_simpson',
#        'sideshow_bob', 'ned_flanders', 'mayor_quimby', 'homer_simpson',
#        'moe_szyslak', 'apu_nahasapeemapetilon', 'nelson_muntz',
#        'principal_skinner', 'milhouse_van_houten', 'marge_simpson',
#        'krusty_the_clown', 'apu_nahasapeemapetilon', 'marge_simpson',
#        'moe_szyslak', 'nelson_muntz', 'milhouse_van_houten',
#        'principal_skinner', 'milhouse_van_houten', 'krusty_the_clown',
#        'ned_flanders', 'nelson_muntz', 'homer_simpson', 'mayor_quimby',
#        'nelson_muntz', 'sideshow_bob', 'bart_simpson', 'mayor_quimby',
#        'homer_simpson', 'ned_flanders', 'charles_montgomery_burns',
#        'krusty_the_clown', 'lisa_simpson', 'principal_skinner',
#        'lisa_simpson', 'apu_nahasapeemapetilon', 'marge_simpson',
#        'sideshow_bob', 'nelson_muntz', 'ned_flanders',
#        'charles_montgomery_burns', 'chief_wiggum', 'krusty_the_clown'],
#       dtype='<U24')

# %%
# !ls
# Out:
# gdrive	label_encoder.pkl  sample_data	test  train

# %%
import pandas as pd
my_submit = pd.read_csv("/content/gdrive/MyDrive/journey-springfield/sample_submission.csv")
my_submit = pd.DataFrame({'Id': test_filenames, 'Expected': preds})
my_submit
# Out:
#              Id                  Expected
# 0      img0.jpg              nelson_muntz
# 1      img1.jpg              bart_simpson
# 2     img10.jpg              ned_flanders
# 3    img100.jpg              chief_wiggum
# 4    img101.jpg    apu_nahasapeemapetilon
# ..          ...                       ...
# 986  img987.jpg              nelson_muntz
# 987  img988.jpg              ned_flanders
# 988  img989.jpg  charles_montgomery_burns
# 989   img99.jpg              chief_wiggum
# 990  img990.jpg          krusty_the_clown
#
# [991 rows x 2 columns]

# %%
# TODO : сделайте сабмит (это важно, если Вы не справляетесь, но дошли до этой ячейки, то сообщите в чат и Вам помогут)

# %%
my_submit.to_csv("/content/gdrive/MyDrive/journey-springfield/sample_submission.csv", index=False)

# %% [markdown]
# ## Приключение?
#
# А теперь самое интересное, мы сделали простенькую сверточную сеть и смогли отправить сабмит, но получившийся скор нас явно не устраивает. Надо с этим что-то сделать.
#
# Несколько срочныйх улучшейни для нашей сети, которые наверняка пришли Вам в голову:
#
#
# *   Учим дольше и изменяем гиперпараметры сети
# *  learning rate, batch size, нормализация картинки и вот это всё
# *   Кто же так строит нейронные сети? А где пулинги и батч нормы? Надо добавлять
# *  Ну разве Адам наше все? [adamW](https://www.fast.ai/2018/07/02/adam-weight-decay/) для практика, [статейка для любителей](https://openreview.net/pdf?id=ryQu7f-RZ) (очень хороший анализ), [наши ](https://github.com/MichaelKonobeev/adashift/) эксперименты для заинтересованных.
#
# * Ну разве это deep learning? Вот ResNet и Inception, которые можно зафайнтьюнить под наши данные, вот это я понимаю (можно и обучить в колабе, а можно и [готовые](https://github.com/Cadene/pretrained-models.pytorch) скачать).
#
# * Данных не очень много, можно их аугументировать и  доучититься на новом датасете ( который уже будет состоять из, как  пример аугументации, перевернутых изображений)
#
# * Стоит подумать об ансамблях
#
#
# Надеюсь, что у Вас получится!
#
# ![alt text](https://pbs.twimg.com/profile_images/798904974986113024/adcQiVdV.jpg)
